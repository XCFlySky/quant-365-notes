# %%
# 课程主题样式（运行一次即可，可折叠隐藏）
from IPython.display import HTML, display
display(HTML('''
<style>
/* ═══════════════════════════════════════════════════════════
   QUANT FINANCE NOTEBOOK THEME — "Parchment & Ink"
   Inspired by vintage financial ledgers and trading floor terminals
   ═══════════════════════════════════════════════════════════ */

@import url('https://fonts.googleapis.com/css2?family=Crimson+Pro:ital,wght@0,300;0,400;0,600;0,700;1,400&family=JetBrains+Mono:wght@400;500;600&family=DM+Sans:wght@400;500;600;700&display=swap');

/* ── Foundation ── */
:root {
  --parchment: #F6F1EB;
  --parchment-deep: #EDE6DB;
  --ivory: #FDFBF8;
  --ink: #1A1A2E;
  --ink-soft: #3D3D56;
  --ink-muted: #6B6B84;
  --ink-faint: #9E9EB5;
  --gold: #C8973E;
  --gold-light: #E8D5A8;
  --gold-glow: rgba(200, 151, 62, 0.08);
  --teal: #2D8E8E;
  --teal-soft: #3AA8A8;
  --teal-bg: rgba(45, 142, 142, 0.06);
  --rust: #B85C38;
  --rust-soft: rgba(184, 92, 56, 0.08);
  --slate: #4A5568;
  --rule: rgba(200, 151, 62, 0.25);
  --shadow-sm: 0 1px 3px rgba(26, 26, 46, 0.04);
  --shadow-md: 0 4px 16px rgba(26, 26, 46, 0.06);
  --shadow-lg: 0 8px 32px rgba(26, 26, 46, 0.08);
  --radius: 5px;
}

/* ── Global Canvas ── */
body,
.jp-LabShell,
#main-panel {
  background-color: var(--parchment) !important;
}

.jp-Notebook,
.jp-NotebookPanel-notebook {
  background-color: var(--parchment) !important;
  padding: 24px 8px !important;
}

/* Subtle paper texture via gradient noise */
.jp-NotebookPanel-notebook::before {
  content: '';
  position: fixed;
  inset: 0;
  background:
    radial-gradient(ellipse at 20% 50%, rgba(200, 151, 62, 0.03) 0%, transparent 50%),
    radial-gradient(ellipse at 80% 20%, rgba(45, 142, 142, 0.02) 0%, transparent 50%);
  pointer-events: none;
  z-index: 0;
}

/* ── Top Bar & Toolbar ── */
#jp-top-bar,
#jp-menu-panel,
.jp-Toolbar {
  background: linear-gradient(180deg, var(--parchment-deep) 0%, var(--parchment) 100%) !important;
  border-bottom: 1px solid var(--rule) !important;
}

.jp-Toolbar {
  box-shadow: var(--shadow-sm) !important;
}

/* ── Cell Base ── */
.jp-Cell {
  background: var(--ivory);
  border-radius: var(--radius);
  margin-bottom: 14px !important;
  box-shadow: var(--shadow-sm);
  border: 1px solid rgba(200, 151, 62, 0.12);
  transition: box-shadow 0.25s ease, border-color 0.25s ease;
  position: relative;
  overflow: visible;
}

.jp-Cell:hover {
  box-shadow: var(--shadow-md);
  border-color: rgba(200, 151, 62, 0.25);
}

.jp-Cell.jp-mod-selected {
  border-color: var(--gold) !important;
  box-shadow: var(--shadow-md), 0 0 0 1px var(--gold-light);
}

/* ── Code Cells ── */
.jp-CodeCell .jp-Cell-inputWrapper {
  border-left: 3px solid var(--teal);
  border-radius: var(--radius) 0 0 var(--radius);
  background: linear-gradient(135deg, var(--teal-bg) 0%, transparent 60%);
}

.jp-CodeCell .jp-Cell-inputWrapper::before {
  content: '>';
  position: absolute;
  left: 12px;
  top: 10px;
  font-family: 'JetBrains Mono', monospace;
  font-size: 11px;
  font-weight: 600;
  color: var(--teal);
  opacity: 0.5;
}

.jp-CodeCell .jp-InputArea-editor {
  font-family: 'JetBrains Mono', monospace !important;
  font-size: 13.5px !important;
  line-height: 1.65 !important;
}

/* Code output area */
.jp-OutputArea {
  border-top: 1px dashed var(--rule);
  margin-top: 2px;
}

.jp-OutputArea-output pre {
  font-family: 'JetBrains Mono', monospace !important;
  font-size: 12.5px !important;
  color: var(--ink-soft);
  line-height: 1.6;
}

/* ── Markdown Cells ── */
.jp-MarkdownCell .jp-Cell-inputWrapper {
  border-left: 3px solid var(--gold);
  border-radius: var(--radius) 0 0 var(--radius);
  background: linear-gradient(135deg, var(--gold-glow) 0%, transparent 60%);
}

/* ── Typography ── */
.jp-RenderedHTMLCommon {
  font-family: 'DM Sans', -apple-system, sans-serif !important;
  font-size: 15px !important;
  line-height: 1.75 !important;
  color: var(--ink) !important;
}

/* Headings */
.jp-RenderedHTMLCommon h1 {
  font-family: 'Crimson Pro', Georgia, serif !important;
  font-weight: 700 !important;
  font-size: 2em !important;
  color: var(--ink) !important;
  margin: 1.2em 0 0.6em !important;
  padding-bottom: 12px !important;
  border-bottom: 2px solid var(--gold) !important;
  letter-spacing: -0.01em;
  position: relative;
}

.jp-RenderedHTMLCommon h1::after {
  content: '';
  position: absolute;
  bottom: -2px;
  left: 0;
  width: 60px;
  height: 2px;
  background: var(--teal);
}

.jp-RenderedHTMLCommon h2 {
  font-family: 'Crimson Pro', Georgia, serif !important;
  font-weight: 600 !important;
  font-size: 1.55em !important;
  color: var(--ink-soft) !important;
  margin: 1em 0 0.5em !important;
  padding-bottom: 8px !important;
  border-bottom: 1px solid var(--rule) !important;
  letter-spacing: -0.005em;
}

.jp-RenderedHTMLCommon h3 {
  font-family: 'DM Sans', sans-serif !important;
  font-weight: 700 !important;
  font-size: 1.25em !important;
  color: var(--teal) !important;
  margin: 0.8em 0 0.4em !important;
  letter-spacing: 0.01em;
}

.jp-RenderedHTMLCommon h4 {
  font-family: 'DM Sans', sans-serif !important;
  font-weight: 600 !important;
  font-size: 1.05em !important;
  color: var(--rust) !important;
  text-transform: uppercase;
  letter-spacing: 0.04em;
  margin: 0.6em 0 0.3em !important;
}

/* ── Tables — Ledger Style ── */
.jp-RenderedHTMLCommon table {
  border-collapse: separate !important;
  border-spacing: 0 !important;
  width: auto;
  margin: 1.2em 0 !important;
  border-radius: var(--radius);
  overflow: hidden;
  box-shadow: var(--shadow-sm);
  border: 1px solid rgba(200, 151, 62, 0.2);
}

.jp-RenderedHTMLCommon table thead th {
  background: linear-gradient(135deg, var(--ink) 0%, var(--ink-soft) 100%) !important;
  color: var(--gold-light) !important;
  font-family: 'DM Sans', sans-serif !important;
  font-weight: 600 !important;
  font-size: 13px !important;
  text-transform: uppercase;
  letter-spacing: 0.06em;
  padding: 11px 16px !important;
  border: none !important;
  text-align: left;
}

.jp-RenderedHTMLCommon table td {
  padding: 9px 16px !important;
  border-bottom: 1px solid rgba(200, 151, 62, 0.12) !important;
  border-right: 1px solid rgba(200, 151, 62, 0.06) !important;
  font-size: 14px !important;
  color: var(--ink-soft);
  transition: background-color 0.15s ease;
}

.jp-RenderedHTMLCommon table tbody tr:nth-child(even) {
  background-color: rgba(200, 151, 62, 0.03);
}

.jp-RenderedHTMLCommon table tbody tr:hover {
  background-color: rgba(45, 142, 142, 0.06) !important;
}

.jp-RenderedHTMLCommon table td:last-child {
  border-right: none !important;
}

/* ── Blockquotes — Callout Cards ── */
.jp-RenderedHTMLCommon blockquote {
  background: linear-gradient(135deg, #FFF9F0 0%, #FFF5E6 100%);
  border: 1px solid rgba(200, 151, 62, 0.2);
  border-left: 4px solid var(--gold) !important;
  border-radius: 0 var(--radius) var(--radius) 0;
  padding: 16px 20px !important;
  margin: 1em 0 !important;
  color: var(--ink-soft) !important;
  font-style: italic;
  position: relative;
  box-shadow: var(--shadow-sm);
}

.jp-RenderedHTMLCommon blockquote::before {
  content: '\201C';
  position: absolute;
  top: -4px;
  left: 12px;
  font-family: 'Crimson Pro', serif;
  font-size: 48px;
  color: var(--gold-light);
  line-height: 1;
  opacity: 0.6;
}

.jp-RenderedHTMLCommon blockquote p {
  margin: 0;
  padding-left: 24px;
}

/* ── Inline Code ── */
.jp-RenderedHTMLCommon code {
  font-family: 'JetBrains Mono', monospace !important;
  font-size: 0.88em !important;
  background: linear-gradient(135deg, rgba(45, 142, 142, 0.08), rgba(45, 142, 142, 0.04));
  color: var(--teal) !important;
  padding: 2px 7px !important;
  border-radius: 3px;
  border: 1px solid rgba(45, 142, 142, 0.12);
}

/* ── Code Blocks in Markdown ── */
.jp-RenderedHTMLCommon pre {
  background: var(--ink) !important;
  color: #E8E6E0 !important;
  border-radius: var(--radius);
  padding: 16px 20px !important;
  box-shadow: var(--shadow-md);
  border: 1px solid rgba(200, 151, 62, 0.15);
  position: relative;
  overflow-x: auto;
}

.jp-RenderedHTMLCommon pre code {
  background: transparent !important;
  color: inherit !important;
  border: none !important;
  padding: 0 !important;
  font-size: 13px !important;
  line-height: 1.7;
}

/* ── Lists ── */
.jp-RenderedHTMLCommon ul li,
.jp-RenderedHTMLCommon ol li {
  margin-bottom: 4px;
  line-height: 1.7;
}

.jp-RenderedHTMLCommon ul li::marker {
  color: var(--gold);
}

.jp-RenderedHTMLCommon ol li::marker {
  color: var(--teal);
  font-weight: 600;
}

/* ── Strong & Emphasis ── */
.jp-RenderedHTMLCommon strong {
  color: var(--ink) !important;
  font-weight: 700;
}

.jp-RenderedHTMLCommon em {
  color: var(--ink-soft);
  font-style: italic;
}

/* ── Links ── */
.jp-RenderedHTMLCommon a {
  color: var(--teal) !important;
  text-decoration: none;
  border-bottom: 1px solid rgba(45, 142, 142, 0.3);
  transition: border-color 0.2s ease, color 0.2s ease;
}

.jp-RenderedHTMLCommon a:hover {
  color: var(--teal-soft) !important;
  border-bottom-color: var(--teal);
}

/* ── Horizontal Rules ── */
.jp-RenderedHTMLCommon hr {
  border: none !important;
  height: 1px;
  background: linear-gradient(90deg, transparent, var(--gold), transparent) !important;
  margin: 2em 0 !important;
}

/* ── Images & Figures ── */
.jp-RenderedHTMLCommon img {
  border-radius: var(--radius);
  box-shadow: var(--shadow-md);
}

/* ── MathJax ── */
.jp-RenderedHTMLCommon .MathJax {
  color: var(--ink) !important;
}

/* ── Scrollbar ── */
.jp-NotebookPanel-notebook::-webkit-scrollbar {
  width: 7px;
}

.jp-NotebookPanel-notebook::-webkit-scrollbar-track {
  background: var(--parchment-deep);
}

.jp-NotebookPanel-notebook::-webkit-scrollbar-thumb {
  background: var(--gold-light);
  border-radius: 4px;
}

.jp-NotebookPanel-notebook::-webkit-scrollbar-thumb:hover {
  background: var(--gold);
}

/* ── Cell Number / Prompt ── */
.jp-InputPrompt,
.jp-OutputPrompt {
  font-family: 'JetBrains Mono', monospace !important;
  font-size: 11px !important;
  color: var(--ink-faint) !important;
  min-width: 60px !important;
}

.jp-InputPrompt {
  color: var(--teal) !important;
  opacity: 0.6;
}

.jp-OutputPrompt {
  color: var(--rust) !important;
  opacity: 0.5;
}

</style>
'''))
# Out:
# <style>
# /* ═══════════════════════════════════════════════════════════
#    QUANT FINANCE NOTEBOOK THEME — "Parchment & Ink"
#    Inspired by vintage financial ledgers and trading floor terminals
#    ═══════════════════════════════════════════════════════════ */
#
# @import url('https://fonts.googleapis.com/css2?family=Crimson+Pro:ital,wght@0,300;0,400;0,600;0,700;1,400&family=JetBrains+Mono:wght@400;500;600&family=DM+Sans:wght@400;500;600;700&display=swap');
#
# /* ── Foundation ── */
# :root {
#   --parchment: #F6F1EB;
#   --parchment-deep: #EDE6DB;
#   --ivory: #FDFBF8;
#   --ink: #1A1A2E;
#   --ink-soft: #3D3D56;
#   --ink-muted: #6B6B84;
#   --ink-faint: #9E9EB5;
#   --gold: #C8973E;
#   --gold-light: #E8D5A8;
#   --gold-glow: rgba(200, 151, 62, 0.08);
#   --teal: #2D8E8E;
#   --teal-soft: #3AA8A8;
#   --teal-bg: rgba(45, 142, 142, 0.06);
#   --rust: #B85C38;
#   --rust-soft: rgba(184, 92, 56, 0.08);
#   --slate: #4A5568;
#   --rule: rgba(200, 151, 62, 0.25);
#   --shadow-sm: 0 1px 3px rgba(26, 26, 46, 0.04);
#   --shadow-md: 0 4px 16px rgba(26, 26, 46, 0.06);
#   --shadow-lg: 0 8px 32px rgba(26, 26, 46, 0.08);
#   --radius: 5px;
# }
#
# /* ── Global Canvas ── */
# body,
# .jp-LabShell,
# #main-panel {
#   background-color: var(--parchment) !important;
# }
#
# .jp-Notebook,
# .jp-NotebookPanel-notebook {
#   background-color: var(--parchment) !important;
#   padding: 24px 8px !important;
# }
#
# /* Subtle paper texture via gradient noise */
# .jp-NotebookPanel-notebook::before {
#   content: '';
#   position: fixed;
#   inset: 0;
#   background:
#     radial-gradient(ellipse at 20% 50%, rgba(200, 151, 62, 0.03) 0%, transparent 50%),
#     radial-gradient(ellipse at 80% 20%, rgba(45, 142, 142, 0.02) 0%, transparent 50%);
#   pointer-events: none;
#   z-index: 0;
# }
#
# /* ── Top Bar & Toolbar ── */
# #jp-top-bar,
# #jp-menu-panel,
# .jp-Toolbar {
#   background: linear-gradient(180deg, var(--parchment-deep) 0%, var(--parchment) 100%) !important;
#   border-bottom: 1px solid var(--rule) !important;
# }
#
# .jp-Toolbar {
#   box-shadow: var(--shadow-sm) !important;
# }
#
# /* ── Cell Base ── */
# .jp-Cell {
#   background: var(--ivory);
#   border-radius: var(--radius);
#   margin-bottom: 14px !important;
#   box-shadow: var(--shadow-sm);
#   border: 1px solid rgba(200, 151, 62, 0.12);
#   transition: box-shadow 0.25s ease, border-color 0.25s ease;
#   position: relative;
#   overflow: visible;
# }
#
# .jp-Cell:hover {
#   box-shadow: var(--shadow-md);
#   border-color: rgba(200, 151, 62, 0.25);
# }
#
# .jp-Cell.jp-mod-selected {
#   border-color: var(--gold) !important;
#   box-shadow: var(--shadow-md), 0 0 0 1px var(--gold-light);
# }
#
# /* ── Code Cells ── */
# .jp-CodeCell .jp-Cell-inputWrapper {
#   border-left: 3px solid var(--teal);
#   border-radius: var(--radius) 0 0 var(--radius);
#   background: linear-gradient(135deg, var(--teal-bg) 0%, transparent 60%);
# }
#
# .jp-CodeCell .jp-Cell-inputWrapper::before {
#   content: '>';
#   position: absolute;
#   left: 12px;
#   top: 10px;
#   font-family: 'JetBrains Mono', monospace;
#   font-size: 11px;
#   font-weight: 600;
#   color: var(--teal);
#   opacity: 0.5;
# }
#
# .jp-CodeCell .jp-InputArea-editor {
#   font-family: 'JetBrains Mono', monospace !important;
#   font-size: 13.5px !important;
#   line-height: 1.65 !important;
# }
#
# /* Code output area */
# .jp-OutputArea {
#   border-top: 1px dashed var(--rule);
#   margin-top: 2px;
# }
#
# .jp-OutputArea-output pre {
#   font-family: 'JetBrains Mono', monospace !important;
#   font-size: 12.5px !important;
#   color: var(--ink-soft);
#   line-height: 1.6;
# }
#
# /* ── Markdown Cells ── */
# .jp-MarkdownCell .jp-Cell-inputWrapper {
#   border-left: 3px solid var(--gold);
#   border-radius: var(--radius) 0 0 var(--radius);
#   background: linear-gradient(135deg, var(--gold-glow) 0%, transparent 60%);
# }
#
# /* ── Typography ── */
# .jp-RenderedHTMLCommon {
#   font-family: 'DM Sans', -apple-system, sans-serif !important;
#   font-size: 15px !important;
#   line-height: 1.75 !important;
#   color: var(--ink) !important;
# }
#
# /* Headings */
# .jp-RenderedHTMLCommon h1 {
#   font-family: 'Crimson Pro', Georgia, serif !important;
#   font-weight: 700 !important;
#   font-size: 2em !important;
#   color: var(--ink) !important;
#   margin: 1.2em 0 0.6em !important;
#   padding-bottom: 12px !important;
#   border-bottom: 2px solid var(--gold) !important;
#   letter-spacing: -0.01em;
#   position: relative;
# }
#
# .jp-RenderedHTMLCommon h1::after {
#   content: '';
#   position: absolute;
#   bottom: -2px;
#   left: 0;
#   width: 60px;
#   height: 2px;
#   background: var(--teal);
# }
#
# .jp-RenderedHTMLCommon h2 {
#   font-family: 'Crimson Pro', Georgia, serif !important;
#   font-weight: 600 !important;
#   font-size: 1.55em !important;
#   color: var(--ink-soft) !important;
#   margin: 1em 0 0.5em !important;
#   padding-bottom: 8px !important;
#   border-bottom: 1px solid var(--rule) !important;
#   letter-spacing: -0.005em;
# }
#
# .jp-RenderedHTMLCommon h3 {
#   font-family: 'DM Sans', sans-serif !important;
#   font-weight: 700 !important;
#   font-size: 1.25em !important;
#   color: var(--teal) !important;
#   margin: 0.8em 0 0.4em !important;
#   letter-spacing: 0.01em;
# }
#
# .jp-RenderedHTMLCommon h4 {
#   font-family: 'DM Sans', sans-serif !important;
#   font-weight: 600 !important;
#   font-size: 1.05em !important;
#   color: var(--rust) !important;
#   text-transform: uppercase;
#   letter-spacing: 0.04em;
#   margin: 0.6em 0 0.3em !important;
# }
#
# /* ── Tables — Ledger Style ── */
# .jp-RenderedHTMLCommon table {
#   border-collapse: separate !important;
#   border-spacing: 0 !important;
#   width: auto;
#   margin: 1.2em 0 !important;
#   border-radius: var(--radius);
#   overflow: hidden;
#   box-shadow: var(--shadow-sm);
#   border: 1px solid rgba(200, 151, 62, 0.2);
# }
#
# .jp-RenderedHTMLCommon table thead th {
#   background: linear-gradient(135deg, var(--ink) 0%, var(--ink-soft) 100%) !important;
#   color: var(--gold-light) !important;
#   font-family: 'DM Sans', sans-serif !important;
#   font-weight: 600 !important;
#   font-size: 13px !important;
#   text-transform: uppercase;
#   letter-spacing: 0.06em;
#   padding: 11px 16px !important;
#   border: none !important;
#   text-align: left;
# }
#
# .jp-RenderedHTMLCommon table td {
#   padding: 9px 16px !important;
#   border-bottom: 1px solid rgba(200, 151, 62, 0.12) !important;
#   border-right: 1px solid rgba(200, 151, 62, 0.06) !important;
#   font-size: 14px !important;
#   color: var(--ink-soft);
#   transition: background-color 0.15s ease;
# }
#
# .jp-RenderedHTMLCommon table tbody tr:nth-child(even) {
#   background-color: rgba(200, 151, 62, 0.03);
# }
#
# .jp-RenderedHTMLCommon table tbody tr:hover {
#   background-color: rgba(45, 142, 142, 0.06) !important;
# }
#
# .jp-RenderedHTMLCommon table td:last-child {
#   border-right: none !important;
# }
#
# /* ── Blockquotes — Callout Cards ── */
# .jp-RenderedHTMLCommon blockquote {
#   background: linear-gradient(135deg, #FFF9F0 0%, #FFF5E6 100%);
#   border: 1px solid rgba(200, 151, 62, 0.2);
#   border-left: 4px solid var(--gold) !important;
#   border-radius: 0 var(--radius) var(--radius) 0;
#   padding: 16px 20px !important;
#   margin: 1em 0 !important;
#   color: var(--ink-soft) !important;
#   font-style: italic;
#   position: relative;
#   box-shadow: var(--shadow-sm);
# }
#
# .jp-RenderedHTMLCommon blockquote::before {
#   content: 'C';
#   position: absolute;
#   top: -4px;
#   left: 12px;
#   font-family: 'Crimson Pro', serif;
#   font-size: 48px;
#   color: var(--gold-light);
#   line-height: 1;
#   opacity: 0.6;
# }
#
# .jp-RenderedHTMLCommon blockquote p {
#   margin: 0;
#   padding-left: 24px;
# }
#
# /* ── Inline Code ── */
# .jp-RenderedHTMLCommon code {
#   font-family: 'JetBrains Mono', monospace !important;
#   font-size: 0.88em !important;
#   background: linear-gradient(135deg, rgba(45, 142, 142, 0.08), rgba(45, 142, 142, 0.04));
#   color: var(--teal) !important;
#   padding: 2px 7px !important;
#   border-radius: 3px;
#   border: 1px solid rgba(45, 142, 142, 0.12);
# }
#
# /* ── Code Blocks in Markdown ── */
# .jp-RenderedHTMLCommon pre {
#   background: var(--ink) !important;
#   color: #E8E6E0 !important;
#   border-radius: var(--radius);
#   padding: 16px 20px !important;
#   box-shadow: var(--shadow-md);
#   border: 1px solid rgba(200, 151, 62, 0.15);
#   position: relative;
#   overflow-x: auto;
# }
#
# .jp-RenderedHTM

# %% [markdown]
# # 第02课：市场数据处理与清洗
#
# ## 模块一：量化交易框架与市场数据工程
#
# ---
#
# **课程目标：**
# - 理解金融数据中的常见陷阱：幸存者偏差、前视偏差、复权
# - 掌握对数收益率与简单收益率的区别和适用场景
# - 理解Point-in-time数据概念
# - 掌握缺失值处理和异常值检测方法
# - 动手实践：复权计算、多标的数据面板、异常值处理
#
# ---
#
# **术语速查表（初学者请先浏览）：**
#
# | 术语 | 含义 |
# |------|------|
# | Survivorship Bias（幸存者偏差） | 只看"活下来"的股票，忽略了退市/破产的，导致高估收益 |
# | Look-ahead Bias（前视偏差/未来信息偏差） | 在回测中不小心用了"未来才知道"的信息，导致结果虚假 |
# | Point-in-time（时点数据） | 在每个时间点上只使用当时真正能获得的信息 |
# | OHLCV | 开盘价(Open)、最高价(High)、最低价(Low)、收盘价(Close)、成交量(Volume) |
# | 复权 | 除权除息后调整历史价格，使其连续可比（不然拆股/分红会导致价格"跳跃"） |
# | Z-score（标准分数） | 衡量一个值偏离平均值多少个标准差，用于检测异常值 |
# | MAD（中位数绝对偏差） | 比Z-score更稳健的异常值检测方法，不容易被极端值影响 |
# | Winsorize（缩尾处理） | 将极端值拉回到指定分位数，保留数据但限制极端值影响 |
# | ffill（前向填充） | 用前一个有效值填补缺失值，常用于处理停牌数据 |

# %% [markdown]
# ## 1. 金融数据中的常见陷阱
#
# 量化交易中，"垃圾进，垃圾出"（Garbage In, Garbage Out）是最重要的原则之一。即使模型再精妙，如果输入数据存在问题，结果也毫无意义。
#
# ### 1.1 幸存者偏差（Survivorship Bias，只看"赢家"导致的偏差）
#
# **定义**：只使用当前存活的标的进行回测，忽略了已经退市、破产、被收购的标的。
#
# **影响**：
# - 高估策略收益：存活下来的股票通常表现较好
# - 低估风险：忽略了可能导致巨额亏损的退市股票
# - 研究显示，幸存者偏差可能导致年化收益率被高估1-2个百分点
#
# **解决方案**：
# - 使用Point-in-time数据集（如CRSP、Wind万德）
# - 确保数据集包含已退市的股票
# - 在每个时间点只使用当时可交易的标的
#
# ### 1.2 前视偏差（Look-Ahead Bias，不小心"穿越"用了未来信息）
#
# **定义**：在策略研究中使用了当时不可能获得的未来信息。
#
# **常见场景**：
# - 使用当日收盘价产生信号并在当日收盘时交易（实际上信号产生时已收盘）
# - 使用事后修正的经济数据（如GDP初值 vs 终值）
# - 使用未来的数据进行特征标准化（如全样本标准化而非滚动标准化）
#
# **解决方案**：
# - 信号延迟一期执行：T日信号 → T+1日交易
# - 使用Point-in-time数据
# - 滚动窗口计算统计量
#
# ### 1.3 复权问题（Corporate Actions Adjustment）
#
# **定义**：股票在发生拆股、分红等公司行为时，价格会出现"跳跃"，如果不调整会导致收益率计算错误。
#
# > **通俗理解**：比如某只股票100元1股，1拆2之后变成50元2股，总价值没变，但如果不复权，看起来价格"暴跌"了50%，会误导分析。复权就是把历史价格调整一下，让价格曲线连续可比。
#
# | 公司行为 | 对价格的影响 | 需要的调整 |
# |---------|------------|----------|
# | 拆股 (Stock Split) | 价格除以拆股比例 | 调整历史价格 |
# | 合股 (Reverse Split) | 价格乘以合股比例 | 调整历史价格 |
# | 现金分红 (Dividend) | 除权日价格下跌 | 前复权或后复权 |
# | 配股 (Rights Issue) | 价格下跌 | 调整历史价格 |
#
# **复权方式**：
# - **前复权（Forward Adjust）**：以最新价格为基准，向前调整历史价格。优点：当前价格是真实价格
# - **后复权（Backward Adjust）**：以最早价格为基准，向后调整。优点：历史价格不变，适合计算长期收益

# %% [markdown]
# ## 2. 对数收益率 vs 简单收益率
#
# ### 简单收益率（Arithmetic Return）
#
# $$R_t = \frac{P_t - P_{t-1}}{P_{t-1}} = \frac{P_t}{P_{t-1}} - 1$$
#
# ### 对数收益率（Logarithmic Return）
#
# $$r_t = \ln\frac{P_t}{P_{t-1}} = \ln P_t - \ln P_{t-1}$$
#
# ### 两者的关系
#
# $$r_t = \ln(1 + R_t)$$
#
# ### 各自的优缺点
#
# | 特性 | 简单收益率 | 对数收益率 |
# |------|-----------|----------|
# | 时间可加性 | 不可加（需要连乘） | 可加（直接求和） |
# | 截面可加性 | 可加（组合收益=加权平均） | 不可加 |
# | 分布假设 | 无特殊要求 | 假设正态分布更合理 |
# | 适用场景 | 组合收益计算 | 时间序列分析、统计建模 |
# | 数值差异 | 当收益率小时，两者近似相等 | 当收益率大时差异明显 |
#
# **实践建议**：
# - 计算组合收益时用**简单收益率**
# - 做时间序列建模时用**对数收益率**
# - 日频数据两者差异很小（<0.01%），可以忽略

# %% [markdown]
# ## 3. Point-in-Time 数据概念
#
# **Point-in-Time（PIT，时点数据）** 是指在每个时间点上，只包含当时实际可获得的信息。
#
# > **通俗理解**：就像考试时不能偷看答案一样，回测策略时不能偷用"未来才公布"的数据。PIT要求我们严格遵守时间线。
#
# ### 为什么PIT很重要？
#
# 以财务数据为例：
#
# ```
# 时间轴:
# ├── Q1结束(3/31) ──── Q1报告发布(4/28) ──── Q2结束(6/30) ──── Q2报告发布(8/15) ──┤
#                       ↑                                      ↑
#               此时才能使用Q1数据              此时才能使用Q2数据
# ```
#
# **错误做法**：在4月1日就使用Q1的财务数据（此时财报尚未发布）
#
# **正确做法**：在4月28日财报发布后才使用Q1数据
#
# ### PIT数据的其他例子
#
# - **指数成分股**：标普500的成分股会定期调整，回测时应使用当时的成分股列表
# - **宏观经济数据**：GDP数据会经历初值、修正值、终值，应使用当时发布的版本
# - **分析师预测**：应使用当时可获得的一致预期，而非事后修正的版本

# %% [markdown]
# ## 4. 数学原理
#
# ### 4.1 复权因子的数学
#
# 复权的核心思想是通过一个**调整因子**来还原公司行为对价格的影响。
#
# 假设一只股票在时间T发生了2:1的拆股：
# - **前复权**：T时刻之前的所有价格都除以2（向前调整历史价格）
# - **后复权**：T时刻之后的价格都乘以2（向后调整新价格）
#
# 分红的处理类似。如果股票在除息日前价格为P，每股分红D，除息后价格理论上变为P-D。前复权会把历史价格向下调整，使得收益率序列能正确反映含红利在内的真实回报。
#
# **前复权公式**：
#
# $$P_{adj} = P_{raw} \times \frac{F_{latest}}{F_t}$$
#
# 其中 $F_t$ 是时间t的复权因子。
#
# | 复权方式 | 基准 | 特点 |
# |---------|------|------|
# | 前复权 | 最新价格不变，调整历史价格 | 当前价格与交易软件一致 |
# | 后复权 | 最早价格不变，调整后续价格 | 正确反映真实的资本增值 |
#
# ### 4.2 异常值检测的数学
#
# #### Z-score 方法
#
# 用大白话说："看这个值离平均多远，用标准差当尺子量一下"。
#
# $$Z = \frac{x - \mu}{\sigma}$$
#
# - $x$：某一个具体的值
# - $\mu$（mu）：所有值的平均数
# - $\sigma$（sigma）：所有值的标准差
#
# Z=2 表示"比平均高了2个标准差"。正态分布里，|Z|>3 的概率不到1%，所以通常将 |Z|>3 视为异常值。
#
# **缺陷**：均值和标准差本身就受异常值的影响。一个极端值会把标准差拉大，导致它自身的Z-score反而不那么大了——就像一个坏学生把全班平均分拉低了，反而显得自己没那么差。
#
# #### MAD 方法（Median Absolute Deviation，中位数绝对偏差）
#
# MAD 更加稳健，因为中位数不受极端值影响：
#
# 1. 算出中位数（median）
# 2. 算"每个值到中位数的距离"
# 3. 取这些距离的中位数，即为 MAD
#
# $$\text{Modified Z} = 0.6745 \times \frac{x - \text{median}}{\text{MAD}}$$
#
# > 0.6745 这个常数是为了让 Modified Z 和传统 Z 在正态分布下数值可比。中位数和 MAD 都不受极端值的影响——一颗老鼠屎坏不了一锅粥。
#
# #### Winsorize（缩尾处理）
#
# 不删除异常值，而是把超出阈值的值截断到阈值水平：
# - 低于1%分位数的值 → 设为1%分位数的值
# - 高于99%分位数的值 → 设为99%分位数的值
#
# 既控制了极端值的影响，又不丢失数据量，在构建因子时特别实用。

# %% [markdown]
# ---
#
# ## 5. Python实践
#
# 接下来我们用代码来实践数据处理与清洗的各个环节。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 100

np.random.seed(42)
print("环境准备完成!")
# Out:
# 环境准备完成!

# %% [markdown]
# ### 5.1 生成包含公司行为的模拟数据

# %%
def generate_raw_stock_data(n_days=1000, seed=42):
    """生成包含拆股和分红事件的原始股票数据"""
    np.random.seed(seed)
    dates = pd.bdate_range(start='2020-01-02', periods=n_days)
    
    # 生成"真实"价格序列（几何布朗运动）
    mu, sigma = 0.12, 0.25
    dt = 1 / 252
    log_ret = (mu - 0.5 * sigma**2) * dt + sigma * np.sqrt(dt) * np.random.randn(n_days)
    true_prices = 100 * np.exp(np.cumsum(log_ret))
    
    # 模拟成交量
    volume = np.random.lognormal(mean=15, sigma=0.5, size=n_days).astype(int)
    
    # 构建DataFrame
    df = pd.DataFrame({
        'date': dates,
        'close': true_prices,
        'volume': volume
    }).set_index('date')
    
    # 添加开高低价（与收盘价一起构成OHLCV中的O/H/L/C，即开盘价/最高价/最低价/收盘价）
    daily_range = df['close'] * np.abs(np.random.randn(n_days)) * 0.02
    df['open'] = df['close'] + np.random.randn(n_days) * daily_range * 0.5
    df['high'] = np.maximum(df['close'], df['open']) + np.abs(np.random.randn(n_days)) * daily_range * 0.3
    df['low'] = np.minimum(df['close'], df['open']) - np.abs(np.random.randn(n_days)) * daily_range * 0.3
    
    # 定义公司行为事件
    events = []
    
    # 1:2拆股，在第300个交易日
    split_idx = 300
    split_date = dates[split_idx]
    events.append({'date': split_date, 'type': 'split', 'ratio': 2})
    
    # 现金分红，每季度一次
    for q in [60, 185, 310, 435, 560, 685, 810, 935]:
        if q < n_days:
            events.append({'date': dates[q], 'type': 'dividend', 'amount': 0.5})
    
    # 应用公司行为到"未复权"价格
    unadj_close = df['close'].copy()
    adj_factors = pd.Series(1.0, index=dates)
    
    for event in sorted(events, key=lambda x: x['date']):
        idx = dates.get_loc(event['date'])
        if event['type'] == 'split':
            # 拆股：之后的价格除以拆股比例
            unadj_close.iloc[idx:] = unadj_close.iloc[idx:] / event['ratio']
            adj_factors.iloc[idx:] = adj_factors.iloc[idx:] * event['ratio']
        elif event['type'] == 'dividend':
            # 分红：除权日价格下跌分红金额
            price_before = unadj_close.iloc[idx - 1] if idx > 0 else unadj_close.iloc[idx]
            div_ratio = 1 - event['amount'] / price_before
            unadj_close.iloc[idx:] = unadj_close.iloc[idx:] * div_ratio
            adj_factors.iloc[:idx] = adj_factors.iloc[:idx] * div_ratio
    
    df['unadj_close'] = unadj_close
    df['adj_factor'] = adj_factors
    
    events_df = pd.DataFrame(events)
    
    return df, events_df


# 生成数据
stock_data, events = generate_raw_stock_data()

print("公司行为事件:")
print(events.to_string(index=False))
print(f"\n数据形状: {stock_data.shape}")
stock_data[['close', 'unadj_close', 'adj_factor']].head(10)
# Out:
# 公司行为事件:
#       date     type  ratio  amount
# 2021-02-25    split    2.0     NaN
# 2020-03-26 dividend    NaN     0.5
# 2020-09-17 dividend    NaN     0.5
# 2021-03-11 dividend    NaN     0.5
# 2021-09-02 dividend    NaN     0.5
# 2022-02-24 dividend    NaN     0.5
# 2022-08-18 dividend    NaN     0.5
# 2023-02-09 dividend    NaN     0.5
# 2023-08-03 dividend    NaN     0.5
#
# 数据形状: (1000, 7)
#                  close  unadj_close  adj_factor
# date
# 2020-01-02  100.820820   100.820820    0.941345
# 2020-01-03  100.636962   100.636962    0.941345
# 2020-01-06  101.704538   101.704538    0.941345
# 2020-01-07  104.210154   104.210154    0.941345
# 2020-01-08  103.863152   103.863152    0.941345
# 2020-01-09  103.517332   103.517332    0.941345
# 2020-01-10  106.161498   106.161498    0.941345
# 2020-01-13  107.490196   107.490196    0.941345
# 2020-01-14  106.735979   106.735979    0.941345
# 2020-01-15  107.689814   107.689814    0.941345

# %% [markdown]
# ### 5.2 复权价格计算

# %%
def forward_adjust(unadj_prices, adj_factor):
    """前复权：以最新价格为基准，向前调整历史价格
    
    前复权价格 = 未复权价格 × (最新复权因子 / 当前复权因子)
    实际上等价于: 未复权价格 × 累积调整因子（归一化到最新日期=1）
    """
    # 归一化复权因子，使最新日期的因子为1
    normalized_factor = adj_factor / adj_factor.iloc[-1]
    return unadj_prices * normalized_factor


def backward_adjust(unadj_prices, adj_factor):
    """后复权：以最早价格为基准，向后调整
    
    后复权价格 = 未复权价格 × (当前复权因子 / 最早复权因子)
    """
    normalized_factor = adj_factor / adj_factor.iloc[0]
    return unadj_prices * normalized_factor


# 计算复权价格
stock_data['fwd_adj_close'] = forward_adjust(stock_data['unadj_close'], stock_data['adj_factor'])
stock_data['bwd_adj_close'] = backward_adjust(stock_data['unadj_close'], stock_data['adj_factor'])

# 可视化对比
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. 未复权价格 — 可以看到拆股和分红导致的价格跳跃
ax = axes[0, 0]
ax.plot(stock_data['unadj_close'], color='blue', linewidth=1)
ax.set_title('未复权价格（可见拆股/分红跳跃）', fontsize=13)
ax.grid(alpha=0.3)

# 标记事件
for _, event in events.iterrows():
    ax.axvline(x=event['date'], color='red', linestyle='--', alpha=0.5)

# 2. 前复权价格
ax = axes[0, 1]
ax.plot(stock_data['fwd_adj_close'], color='green', linewidth=1)
ax.set_title('前复权价格（当前价格真实）', fontsize=13)
ax.grid(alpha=0.3)

# 3. 后复权价格
ax = axes[1, 0]
ax.plot(stock_data['bwd_adj_close'], color='orange', linewidth=1)
ax.set_title('后复权价格（历史价格不变，适合计算长期收益）', fontsize=13)
ax.grid(alpha=0.3)

# 4. "真实"价格对比
ax = axes[1, 1]
ax.plot(stock_data['close'], label='真实连续价格', color='black', linewidth=1.5)
ax.plot(stock_data['fwd_adj_close'], label='前复权价格', color='green', linewidth=1, alpha=0.7)
ax.set_title('真实价格 vs 前复权价格', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

plt.suptitle('复权价格对比', fontsize=15, y=1.02)
plt.tight_layout()
plt.show()

# 验证收益率计算
print("\n收益率验证（拆股日前后）:")
split_date = events[events['type'] == 'split']['date'].iloc[0]
split_idx = stock_data.index.get_loc(split_date)
print(f"拆股日期: {split_date.strftime('%Y-%m-%d')}")
print(f"未复权收益率: {stock_data['unadj_close'].iloc[split_idx] / stock_data['unadj_close'].iloc[split_idx-1] - 1:.4f} (包含拆股跳跃，错误!)")
print(f"前复权收益率: {stock_data['fwd_adj_close'].iloc[split_idx] / stock_data['fwd_adj_close'].iloc[split_idx-1] - 1:.4f} (正确)")
print(f"真实收益率:   {stock_data['close'].iloc[split_idx] / stock_data['close'].iloc[split_idx-1] - 1:.4f}")
# Out:
# 收益率验证（拆股日前后）:
# 拆股日期: 2021-02-25
# 未复权收益率: -0.5063 (包含拆股跳跃，错误!)
# 前复权收益率: -0.0126 (正确)
# 真实收益率:   -0.0126

# %% [markdown]
# ### 5.3 对数收益率 vs 简单收益率实战对比

# %%
# 使用前复权价格计算收益率
prices = stock_data['fwd_adj_close']

# 简单收益率
simple_returns = prices.pct_change().dropna()

# 对数收益率
log_returns = np.log(prices / prices.shift(1)).dropna()

# 对比
comparison = pd.DataFrame({
    '简单收益率': simple_returns,
    '对数收益率': log_returns,
    '差异': simple_returns - log_returns,
    '差异(bp)': (simple_returns - log_returns) * 10000  # 基点
})

print("简单收益率 vs 对数收益率统计:")
print(f"平均绝对差异: {comparison['差异'].abs().mean():.6f} ({comparison['差异(bp)'].abs().mean():.2f} bp)")
print(f"最大差异:     {comparison['差异'].abs().max():.6f} ({comparison['差异(bp)'].abs().max():.2f} bp)")
print(f"\n日频数据下两者差异很小，但月频或年频时差异会显著增大。")

# 验证时间可加性
print("\n=== 时间可加性验证 ===")
# 对数收益率：时间上直接求和
total_log_return = log_returns.sum()
actual_total = np.log(prices.iloc[-1] / prices.iloc[0])
print(f"对数收益率求和: {total_log_return:.6f}")
print(f"实际总对数收益: {actual_total:.6f}")
print(f"差异: {abs(total_log_return - actual_total):.10f} (几乎为零)")

print("\n简单收益率需要连乘:")
total_simple_product = (1 + simple_returns).prod() - 1
actual_simple = prices.iloc[-1] / prices.iloc[0] - 1
print(f"简单收益率连乘: {total_simple_product:.6f}")
print(f"实际总简单收益: {actual_simple:.6f}")
print(f"差异: {abs(total_simple_product - actual_simple):.10f}")

# 可视化
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax = axes[0]
ax.scatter(simple_returns, log_returns, alpha=0.3, s=5)
ax.plot([-0.1, 0.1], [-0.1, 0.1], 'r--', linewidth=1, label='y=x')
ax.set_xlabel('简单收益率')
ax.set_ylabel('对数收益率')
ax.set_title('简单收益率 vs 对数收益率（日频）', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

ax = axes[1]
# 月频对比
monthly_simple = prices.resample('ME').last().pct_change().dropna()
monthly_log = np.log(prices.resample('ME').last() / prices.resample('ME').last().shift(1)).dropna()
ax.scatter(monthly_simple, monthly_log, alpha=0.5, s=20)
ax.plot([-0.2, 0.2], [-0.2, 0.2], 'r--', linewidth=1, label='y=x')
ax.set_xlabel('简单收益率')
ax.set_ylabel('对数收益率')
ax.set_title('简单收益率 vs 对数收益率（月频，差异更明显）', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 简单收益率 vs 对数收益率统计:
# 平均绝对差异: 0.000119 (1.19 bp)
# 最大差异:     0.001901 (19.01 bp)
#
# 日频数据下两者差异很小，但月频或年频时差异会显著增大。
#
# === 时间可加性验证 ===
# 对数收益率求和: 0.648459
# 实际总对数收益: 0.648459
# 差异: 0.0000000000 (几乎为零)
#
# 简单收益率需要连乘:
# 简单收益率连乘: 0.912591
# 实际总简单收益: 0.912591
# 差异: 0.0000000000

# %% [markdown]
# ### 5.4 处理停牌与缺失值

# %%
def generate_multi_stock_panel(n_stocks=5, n_days=500, seed=42):
    """生成多标的日线数据面板，包含停牌和缺失值"""
    np.random.seed(seed)
    dates = pd.bdate_range(start='2022-01-03', periods=n_days)
    
    stock_names = [f'Stock_{chr(65+i)}' for i in range(n_stocks)]  # Stock_A, Stock_B, ...
    
    all_data = {}
    for i, name in enumerate(stock_names):
        mu = np.random.uniform(0.05, 0.20)
        sigma = np.random.uniform(0.15, 0.35)
        S0 = np.random.uniform(20, 200)
        
        dt = 1 / 252
        log_ret = (mu - 0.5 * sigma**2) * dt + sigma * np.sqrt(dt) * np.random.randn(n_days)
        prices = S0 * np.exp(np.cumsum(log_ret))
        volume = np.random.lognormal(mean=14, sigma=0.8, size=n_days).astype(int)
        
        # 模拟停牌（随机选择一些连续日期设为NaN）
        suspension_starts = np.random.choice(range(50, n_days - 30), size=2 + i % 3, replace=False)
        for start in suspension_starts:
            duration = np.random.randint(1, 10)
            end = min(start + duration, n_days)
            prices[start:end] = np.nan
            volume[start:end] = 0
        
        # 模拟随机缺失
        random_missing = np.random.choice(range(n_days), size=5, replace=False)
        prices[random_missing] = np.nan
        
        all_data[name] = pd.DataFrame({
            'close': prices,
            'volume': volume
        }, index=dates)
    
    # 构建面板
    price_panel = pd.DataFrame({name: data['close'] for name, data in all_data.items()})
    volume_panel = pd.DataFrame({name: data['volume'] for name, data in all_data.items()})
    
    return price_panel, volume_panel


# 生成多标的面板
price_panel, volume_panel = generate_multi_stock_panel(n_stocks=5, n_days=500)

# 缺失值统计
missing_stats = pd.DataFrame({
    '总天数': len(price_panel),
    '缺失天数': price_panel.isna().sum(),
    '缺失比例': price_panel.isna().mean(),
    '最长连续缺失': [price_panel[col].isna().astype(int).groupby(
        price_panel[col].notna().astype(int).cumsum()).sum().max() 
        for col in price_panel.columns]
})

print("缺失值统计:")
print(missing_stats)
print(f"\n面板形状: {price_panel.shape}")
# Out:
# 缺失值统计:
#          总天数  缺失天数   缺失比例  最长连续缺失
# Stock_A  500    14  0.028       6
# Stock_B  500    22  0.044       9
# Stock_C  500    33  0.066       9
# Stock_D  500    20  0.040       9
# Stock_E  500    19  0.038       6
#
# 面板形状: (500, 5)

# %%
# 缺失值处理方法对比
def handle_missing_values(prices, method='ffill'):
    """处理缺失值的不同方法"""
    if method == 'ffill':
        # ffill = forward fill（前向填充）：用前一个有效值填补缺失值
        # 最常用于停牌场景：假设停牌期间价格保持不变
        return prices.ffill()
    elif method == 'linear':
        # 线性插值
        return prices.interpolate(method='linear')
    elif method == 'drop':
        # 直接删除
        return prices.dropna()
    elif method == 'ffill_limit':
        # 有限制的向前填充（最多填充5天）
        return prices.ffill(limit=5)
    else:
        raise ValueError(f"Unknown method: {method}")


# 对Stock_A展示不同方法的效果
stock_a = price_panel['Stock_A'].copy()

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

methods = {
    '原始数据（含缺失值）': stock_a,
    '向前填充 (ffill)': handle_missing_values(stock_a, 'ffill'),
    '线性插值 (interpolate)': handle_missing_values(stock_a, 'linear'),
    '有限填充 (ffill, limit=5)': handle_missing_values(stock_a, 'ffill_limit')
}

for ax, (title, data) in zip(axes.flat, methods.items()):
    ax.plot(data, linewidth=1)
    # 标记原始缺失位置
    missing_mask = stock_a.isna()
    if not missing_mask.all() and title != '原始数据（含缺失值）':
        filled_values = data[missing_mask].dropna()
        if len(filled_values) > 0:
            ax.scatter(filled_values.index, filled_values.values, 
                      color='red', s=15, zorder=5, label='填充值')
            ax.legend(fontsize=9)
    ax.set_title(title, fontsize=12)
    ax.grid(alpha=0.3)

plt.suptitle('缺失值处理方法对比 (Stock_A)', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

print("\n实践建议:")
print("- 停牌: 使用ffill（假设停牌期间价格不变）")
print("- 短期缺失(<3天): 可用线性插值")
print("- 长期缺失(>10天): 考虑从分析中排除该标的")
print("- 计算收益率前: 先填充缺失值，再计算")
# Out:
# 实践建议:
# - 停牌: 使用ffill（假设停牌期间价格不变）
# - 短期缺失(<3天): 可用线性插值
# - 长期缺失(>10天): 考虑从分析中排除该标的
# - 计算收益率前: 先填充缺失值，再计算

# %%
# 构建干净的多标的数据面板
# 步骤: ffill填充 → 删除仍然有NaN的行 → 计算收益率

clean_prices = price_panel.ffill().bfill()  # 先前填充，再后填充处理开头的NaN

print(f"清洗前缺失值: {price_panel.isna().sum().sum()}")
print(f"清洗后缺失值: {clean_prices.isna().sum().sum()}")

# 计算收益率面板
returns_panel = clean_prices.pct_change().dropna()

# 可视化归一化价格
fig, ax = plt.subplots(figsize=(14, 6))
normalized = clean_prices / clean_prices.iloc[0] * 100
for col in normalized.columns:
    ax.plot(normalized[col], label=col, linewidth=1.2)

ax.set_title('多标的归一化价格走势（基期=100）', fontsize=14)
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 相关性矩阵
corr_matrix = returns_panel.corr()
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(corr_matrix.values, cmap='RdBu_r', vmin=-1, vmax=1)
ax.set_xticks(range(len(corr_matrix)))
ax.set_xticklabels(corr_matrix.columns, rotation=45)
ax.set_yticks(range(len(corr_matrix)))
ax.set_yticklabels(corr_matrix.columns)
for i in range(len(corr_matrix)):
    for j in range(len(corr_matrix)):
        ax.text(j, i, f'{corr_matrix.iloc[i,j]:.2f}', ha='center', va='center', fontsize=11)
plt.colorbar(im, ax=ax)
ax.set_title('收益率相关性矩阵', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# 清洗前缺失值: 108
# 清洗后缺失值: 0

# %% [markdown]
# ### 5.5 异常值检测与Winsorize（缩尾处理）
#
# > **什么是异常值？** 比如某天的收益率是+30%，而其他日子都在-3%到+3%之间，这个+30%就是异常值。异常值可能是真实的极端事件，也可能是数据错误。
# >
# > **Winsorize（缩尾处理）** 的思路：不删除异常值，而是把极端值"拉回"到一个合理范围（比如1%和99%分位数），既保留了数据量，又减少了极端值的影响。

# %%
def detect_outliers_zscore(series, threshold=3.0):
    """Z-score（标准分数）方法检测异常值
    
    Z = (x - mean) / std
    即：这个值偏离平均值多少个标准差？
    |Z| > threshold（默认3）视为异常值
    
    通俗理解：如果大家平均考70分，标准差10分，你考了100分，
    Z = (100-70)/10 = 3，说明你偏离平均值3个标准差，属于异常值。
    
    缺点: 均值和标准差本身受异常值影响
    """
    z_scores = (series - series.mean()) / series.std()
    outlier_mask = z_scores.abs() > threshold
    return outlier_mask, z_scores


def detect_outliers_mad(series, threshold=3.0):
    """MAD（中位数绝对偏差，Median Absolute Deviation）方法检测异常值
    
    MAD = median(|x - median(x)|)  即所有值与中位数的距离的中位数
    Modified Z = 0.6745 * (x - median) / MAD
    
    优点: 用中位数替代均值，比Z-score更稳健，不受极端值影响
    通俗理解：Z-score用"平均值"做参考，容易被极端值带偏；
    MAD用"中位数"做参考，即使有极端值也不受影响。
    """
    median = series.median()
    mad = (series - median).abs().median()
    if mad == 0:
        mad = 1e-10  # 避免除零
    modified_z = 0.6745 * (series - median) / mad
    outlier_mask = modified_z.abs() > threshold
    return outlier_mask, modified_z


def winsorize(series, lower_pct=0.01, upper_pct=0.99):
    """Winsorize（缩尾处理）：将超出分位数的值截断到分位数边界
    
    不同于删除异常值，Winsorize保留了所有数据点，只是限制了极端值。
    比如设 lower_pct=0.01, upper_pct=0.99：
    - 低于1%分位数的值 → 拉回到1%分位数
    - 高于99%分位数的值 → 拉回到99%分位数
    """
    lower = series.quantile(lower_pct)
    upper = series.quantile(upper_pct)
    return series.clip(lower=lower, upper=upper)


# 使用Stock_A的收益率进行演示
ret_a = returns_panel['Stock_A'].copy()

# 人为注入一些异常值以演示效果
np.random.seed(123)
outlier_indices = np.random.choice(ret_a.index, size=5, replace=False)
ret_a_with_outliers = ret_a.copy()
for idx in outlier_indices:
    ret_a_with_outliers[idx] = np.random.choice([-1, 1]) * np.random.uniform(0.15, 0.30)

# 检测异常值
zscore_mask, z_scores = detect_outliers_zscore(ret_a_with_outliers, threshold=3.0)
mad_mask, mad_scores = detect_outliers_mad(ret_a_with_outliers, threshold=3.0)

print("异常值检测结果:")
print(f"Z-score方法 (|Z|>3): 检测到 {zscore_mask.sum()} 个异常值")
print(f"MAD方法 (|Modified Z|>3): 检测到 {mad_mask.sum()} 个异常值")

# Winsorize处理
ret_winsorized = winsorize(ret_a_with_outliers, lower_pct=0.01, upper_pct=0.99)

print(f"\nWinsorize前 - 范围: [{ret_a_with_outliers.min():.4f}, {ret_a_with_outliers.max():.4f}]")
print(f"Winsorize后 - 范围: [{ret_winsorized.min():.4f}, {ret_winsorized.max():.4f}]")
# Out:
# 异常值检测结果:
# Z-score方法 (|Z|>3): 检测到 5 个异常值
# MAD方法 (|Modified Z|>3): 检测到 7 个异常值
#
# Winsorize前 - 范围: [-0.2313, 0.2519]
# Winsorize后 - 范围: [-0.0476, 0.0754]

# %%
# 可视化异常值检测
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. 收益率时序与异常值标记
ax = axes[0, 0]
ax.plot(ret_a_with_outliers, color='blue', linewidth=0.8, alpha=0.7)
outliers = ret_a_with_outliers[zscore_mask]
ax.scatter(outliers.index, outliers.values, color='red', s=40, zorder=5, label=f'异常值 ({len(outliers)}个)')
ax.set_title('Z-score异常值检测 (|Z|>3)', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

# 2. MAD方法
ax = axes[0, 1]
ax.plot(ret_a_with_outliers, color='blue', linewidth=0.8, alpha=0.7)
outliers_mad = ret_a_with_outliers[mad_mask]
ax.scatter(outliers_mad.index, outliers_mad.values, color='orange', s=40, zorder=5, label=f'异常值 ({len(outliers_mad)}个)')
ax.set_title('MAD异常值检测 (|Modified Z|>3)', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

# 3. Winsorize前后分布对比
ax = axes[1, 0]
ax.hist(ret_a_with_outliers, bins=60, alpha=0.5, label='原始', color='blue', density=True)
ax.hist(ret_winsorized, bins=60, alpha=0.5, label='Winsorize后', color='green', density=True)
ax.set_title('Winsorize前后收益率分布', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

# 4. Q-Q图
ax = axes[1, 1]
sorted_data = np.sort(ret_a_with_outliers.dropna())
n = len(sorted_data)
theoretical = stats.norm.ppf(np.arange(1, n + 1) / (n + 1))
ax.scatter(theoretical, sorted_data, alpha=0.5, s=10)
ax.plot([theoretical.min(), theoretical.max()], [theoretical.min() * ret_a_with_outliers.std() + ret_a_with_outliers.mean(),
         theoretical.max() * ret_a_with_outliers.std() + ret_a_with_outliers.mean()],
        'r--', linewidth=1, label='正态分布参考线')
ax.set_xlabel('理论分位数')
ax.set_ylabel('样本分位数')
ax.set_title('Q-Q图（检验正态性）', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print("\n方法选择建议:")
print("- Z-score: 简单快速，但受极端值影响（不够稳健）")
print("- MAD: 更稳健，推荐用于金融数据")
print("- Winsorize: 保留数据量，适合构建因子时使用")
print("- 实际中常用: Winsorize(1%, 99%) + MAD检测")
# Out:
# 方法选择建议:
# - Z-score: 简单快速，但受极端值影响（不够稳健）
# - MAD: 更稳健，推荐用于金融数据
# - Winsorize: 保留数据量，适合构建因子时使用
# - 实际中常用: Winsorize(1%, 99%) + MAD检测

# %% [markdown]
# ### 5.6 处理不同交易日历

# %%
def create_trading_calendars():
    """创建不同市场的交易日历示例
    
    不同市场有不同的假日和交易时间，跨市场策略必须正确处理。
    """
    # 生成2024年的工作日
    all_bdays = pd.bdate_range(start='2024-01-01', end='2024-12-31')
    
    # 美国市场假日（简化版）
    us_holidays = pd.to_datetime([
        '2024-01-01',  # 新年
        '2024-01-15',  # MLK Day
        '2024-02-19',  # Presidents Day
        '2024-03-29',  # Good Friday
        '2024-05-27',  # Memorial Day
        '2024-06-19',  # Juneteenth
        '2024-07-04',  # Independence Day
        '2024-09-02',  # Labor Day
        '2024-11-28',  # Thanksgiving
        '2024-12-25',  # Christmas
    ])
    
    # 中国A股假日（简化版）
    cn_holidays = pd.to_datetime([
        '2024-01-01',  # 元旦
        '2024-02-09', '2024-02-12', '2024-02-13', '2024-02-14',
        '2024-02-15', '2024-02-16',  # 春节
        '2024-04-04', '2024-04-05',  # 清明
        '2024-05-01', '2024-05-02', '2024-05-03',  # 劳动节
        '2024-06-10',  # 端午
        '2024-09-16', '2024-09-17',  # 中秋
        '2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04',
        '2024-10-07',  # 国庆
    ])
    
    us_trading_days = all_bdays[~all_bdays.isin(us_holidays)]
    cn_trading_days = all_bdays[~all_bdays.isin(cn_holidays)]
    
    return us_trading_days, cn_trading_days


us_calendar, cn_calendar = create_trading_calendars()

print(f"2024年美股交易日: {len(us_calendar)}天")
print(f"2024年A股交易日: {len(cn_calendar)}天")
print(f"共同交易日: {len(us_calendar.intersection(cn_calendar))}天")
print(f"仅美股交易日: {len(us_calendar.difference(cn_calendar))}天")
print(f"仅A股交易日: {len(cn_calendar.difference(us_calendar))}天")
# Out:
# 2024年美股交易日: 252天
# 2024年A股交易日: 242天
# 共同交易日: 233天
# 仅美股交易日: 19天
# 仅A股交易日: 9天

# %%
# 模拟跨市场数据对齐
np.random.seed(42)

# 生成美股和A股数据
us_prices = pd.Series(
    100 * np.exp(np.cumsum(np.random.randn(len(us_calendar)) * 0.01)),
    index=us_calendar, name='US_ETF'
)
cn_prices = pd.Series(
    50 * np.exp(np.cumsum(np.random.randn(len(cn_calendar)) * 0.015)),
    index=cn_calendar, name='CN_ETF'
)

# 直接合并会有大量NaN
combined_raw = pd.DataFrame({'US_ETF': us_prices, 'CN_ETF': cn_prices})
print(f"直接合并后:")
print(f"  总行数: {len(combined_raw)}")
print(f"  US_ETF缺失: {combined_raw['US_ETF'].isna().sum()}")
print(f"  CN_ETF缺失: {combined_raw['CN_ETF'].isna().sum()}")

# 方法1: 取交集（只保留双方都交易的日期）
common_dates = us_calendar.intersection(cn_calendar)
combined_inner = combined_raw.loc[common_dates].dropna()

# 方法2: 向前填充（用最近的收盘价填充）
combined_ffill = combined_raw.ffill().dropna()

print(f"\n方法1 (取交集): {len(combined_inner)}行")
print(f"方法2 (ffill):   {len(combined_ffill)}行")

# 可视化
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax = axes[0]
ax.plot(combined_inner.index, combined_inner['US_ETF'] / combined_inner['US_ETF'].iloc[0],
        label='US_ETF', linewidth=1.2)
ax.plot(combined_inner.index, combined_inner['CN_ETF'] / combined_inner['CN_ETF'].iloc[0],
        label='CN_ETF', linewidth=1.2)
ax.set_title('方法1: 取交集日期', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(combined_ffill.index, combined_ffill['US_ETF'] / combined_ffill['US_ETF'].iloc[0],
        label='US_ETF', linewidth=1.2)
ax.plot(combined_ffill.index, combined_ffill['CN_ETF'] / combined_ffill['CN_ETF'].iloc[0],
        label='CN_ETF', linewidth=1.2)
ax.set_title('方法2: 向前填充', fontsize=13)
ax.legend()
ax.grid(alpha=0.3)

plt.suptitle('跨市场数据对齐方法对比', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

print("\n实践建议:")
print("- 计算相关性、回归: 使用交集日期，确保数据同步")
print("- 构建组合/计算市值: 使用ffill，避免数据断裂")
print("- 重要: ffill会引入假的'零收益日'，计算波动率时需注意")
# Out:
# 直接合并后:
#   总行数: 261
#   US_ETF缺失: 9
#   CN_ETF缺失: 19
#
# 方法1 (取交集): 233行
# 方法2 (ffill):   261行
# 实践建议:
# - 计算相关性、回归: 使用交集日期，确保数据同步
# - 构建组合/计算市值: 使用ffill，避免数据断裂
# - 重要: ffill会引入假的'零收益日'，计算波动率时需注意

# %% [markdown]
# ### 5.7 综合实践：构建干净的数据管道

# %%
class DataPipeline:
    """简单的数据清洗管道
    
    实现了从原始数据到干净数据面板的完整流程：
    1. 缺失值处理
    2. 异常值处理
    3. 收益率计算
    4. 数据质量报告
    """
    
    def __init__(self, prices, max_missing_pct=0.1, winsorize_pct=(0.01, 0.99)):
        self.raw_prices = prices.copy()
        self.max_missing_pct = max_missing_pct
        self.winsorize_pct = winsorize_pct
        self.report = {}
        
    def run(self):
        """运行完整的数据清洗管道"""
        print("=" * 60)
        print("数据清洗管道运行中...")
        print("=" * 60)
        
        # Step 1: 过滤缺失值过多的标的
        missing_pct = self.raw_prices.isna().mean()
        valid_cols = missing_pct[missing_pct <= self.max_missing_pct].index.tolist()
        dropped_cols = missing_pct[missing_pct > self.max_missing_pct].index.tolist()
        
        print(f"\n[Step 1] 过滤缺失值 > {self.max_missing_pct:.0%} 的标的")
        print(f"  保留: {len(valid_cols)}个标的, 删除: {len(dropped_cols)}个标的")
        if dropped_cols:
            print(f"  被删除的标的: {dropped_cols}")
        
        prices = self.raw_prices[valid_cols].copy()
        
        # Step 2: 填充缺失值
        print(f"\n[Step 2] 填充缺失值 (ffill + bfill)")
        n_missing_before = prices.isna().sum().sum()
        prices = prices.ffill().bfill()
        n_missing_after = prices.isna().sum().sum()
        print(f"  填充前: {n_missing_before}个NaN → 填充后: {n_missing_after}个NaN")
        
        # Step 3: 计算收益率
        print(f"\n[Step 3] 计算收益率")
        returns = prices.pct_change().iloc[1:]  # 删除第一行NaN
        print(f"  收益率面板: {returns.shape[0]}天 × {returns.shape[1]}标的")
        
        # Step 4: 检测和处理异常值
        print(f"\n[Step 4] 异常值检测与Winsorize")
        n_outliers_total = 0
        returns_clean = returns.copy()
        for col in returns_clean.columns:
            mask, _ = detect_outliers_mad(returns_clean[col], threshold=5.0)
            n_outliers = mask.sum()
            n_outliers_total += n_outliers
            # Winsorize
            returns_clean[col] = winsorize(returns_clean[col], 
                                           self.winsorize_pct[0], self.winsorize_pct[1])
        print(f"  检测到 {n_outliers_total} 个异常值 (MAD, |Z|>5)")
        print(f"  已进行Winsorize处理 ({self.winsorize_pct[0]:.0%}, {self.winsorize_pct[1]:.0%})")
        
        # Step 5: 数据质量报告
        print(f"\n[Step 5] 数据质量报告")
        quality = pd.DataFrame({
            '标的': valid_cols,
            '日均收益率(bp)': (returns_clean.mean() * 10000).round(2),
            '日波动率(%)': (returns_clean.std() * 100).round(3),
            '年化收益率(%)': (returns_clean.mean() * 252 * 100).round(2),
            '年化波动率(%)': (returns_clean.std() * np.sqrt(252) * 100).round(2),
            '偏度': returns_clean.skew().round(3),
            '峰度': returns_clean.kurtosis().round(3),
        }).set_index('标的')
        print(quality)
        
        self.clean_prices = prices
        self.clean_returns = returns_clean
        self.quality_report = quality
        
        print(f"\n管道运行完成!")
        return returns_clean


# 运行管道
pipeline = DataPipeline(price_panel, max_missing_pct=0.15)
clean_returns = pipeline.run()
# Out:
# ============================================================
# 数据清洗管道运行中...
# ============================================================
#
# [Step 1] 过滤缺失值 > 15% 的标的
#   保留: 5个标的, 删除: 0个标的
#
# [Step 2] 填充缺失值 (ffill + bfill)
#   填充前: 108个NaN → 填充后: 0个NaN
#
# [Step 3] 计算收益率
#   收益率面板: 499天 × 5标的
#
# [Step 4] 异常值检测与Winsorize
#   检测到 0 个异常值 (MAD, |Z|>5)
#   已进行Winsorize处理 (1%, 99%)
#
# [Step 5] 数据质量报告
#          日均收益率(bp)  日波动率(%)  年化收益率(%)  年化波动率(%)     偏度     峰度
# 标的
# Stock_A      19.98    2.079     50.36     33.00  0.079 -0.259
# Stock_B      11.53    1.810     29.06     28.73  0.142 -0.090
# Stock_C       1.54    1.067      3.89     16.93 -0.068 -0.160
# Stock_D       1.56    1.928      3.93     30.60 -0.163 -0.032
# Stock_E       0.92    1.274      2.32     20.22  0.026 -0.256
#
# 管道运行完成!

# %%
# 最终可视化：清洗后的数据质量检查
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. 累积收益
ax = axes[0, 0]
cum_ret = (1 + clean_returns).cumprod()
for col in cum_ret.columns:
    ax.plot(cum_ret[col], label=col, linewidth=1.2)
ax.set_title('累积收益（清洗后数据）', fontsize=13)
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

# 2. 箱线图
ax = axes[0, 1]
bp = ax.boxplot([clean_returns[col].values for col in clean_returns.columns],
                labels=clean_returns.columns, patch_artist=True)
colors = plt.cm.Set3(np.linspace(0, 1, len(clean_returns.columns)))
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
ax.set_title('收益率箱线图', fontsize=13)
ax.grid(alpha=0.3)

# 3. 滚动波动率
ax = axes[1, 0]
roll_vol = clean_returns.rolling(20).std() * np.sqrt(252) * 100
for col in roll_vol.columns:
    ax.plot(roll_vol[col], label=col, linewidth=1)
ax.set_title('20日滚动年化波动率(%)', fontsize=13)
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

# 4. 滚动相关性 (Stock_A vs Stock_B)
ax = axes[1, 1]
if 'Stock_A' in clean_returns.columns and 'Stock_B' in clean_returns.columns:
    roll_corr = clean_returns['Stock_A'].rolling(60).corr(clean_returns['Stock_B'])
    ax.plot(roll_corr, color='purple', linewidth=1)
    ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5)
    ax.set_title('60日滚动相关性 (Stock_A vs Stock_B)', fontsize=13)
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 6. 实战思维与经验分享
#
# **第一，复权问题比你想象的更复杂。** 不同的数据供应商对分红的处理方式不同，有些是税前、有些是税后。有些供应商的复权因子会追溯调整，如果你的系统没有及时更新，就会出现历史数据"变化"的诡异情况——昨天下载的2020年数据和今天下载的不一样了！建议自己维护一套复权逻辑，不要完全依赖供应商。
#
# **第二，前视偏差无处不在，而且极难发现。** 曾经有一个团队的策略回测出了年化40%的惊人收益率，后来发现是因为他们用的指数成分股数据没有做Point-in-Time处理——2015年的回测用的是2020年的沪深300成分股列表。那些在2020年被纳入沪深300的股票，在2015年往往还是中小盘股，本身就有超额收益。一旦修正了这个偏差，收益率直接砍半。
#
# **第三，异常值的处理要因地制宜。** 在构建因子时，Winsorize（缩尾处理）是最安全的选择；但在风险模型中，你反而需要保留极端值，因为风险模型的目的就是评估极端情况下的损失。不同场景下的处理方式是不一样的，不存在"一招鲜吃遍天"的方案。
#
# **第四，数据管道要自动化且可追溯。** 在华尔街，一个成熟的量化团队的数据管道都是全自动的，每天凌晨自动拉取数据、清洗、入库，并且会生成数据质量报告。如果某天某只股票的收益率超过了20%，系统会自动标记并通知研究员。人工干预应该是例外而非常态。

# %% [markdown]
# ---
#
# ## 课程小结
#
# 本课我们学习了：
#
# 1. **金融数据陷阱**：幸存者偏差、前视偏差、复权问题 — 这些是回测失效的主要原因
# 2. **收益率计算**：简单收益率适用于组合计算，对数收益率适用于时序建模
# 3. **Point-in-Time**：确保在每个时间点只使用当时可获得的信息
# 4. **缺失值处理**：ffill（前向填充）、插值、排除 — 根据缺失原因选择方法
# 5. **异常值处理**：Z-score（标准分数检测）、MAD（中位数绝对偏差，更稳健）、Winsorize（缩尾处理，最实用）
# 6. **交易日历**：跨市场策略需要正确处理不同市场的交易日
#
# ### 课后思考
#
# 1. 如果你的回测使用的是当前沪深300的成分股，可能存在什么偏差？
# 2. 为什么Winsorize通常比直接删除异常值更好？
# 3. 在什么情况下，简单收益率和对数收益率的差异会特别大？
